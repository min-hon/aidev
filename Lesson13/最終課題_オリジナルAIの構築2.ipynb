# %%
import random
import string
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

pd.options.display.max_columns = None

label_dict = {i: c for i, c in enumerate(string.ascii_uppercase[:25])}

# %%
train_base = pd.read_csv("./sign/sign_mnist_train.csv")
test_base = pd.read_csv("./sign/sign_mnist_test.csv")

# %%
train_base.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  pixel10  pixel11  pixel12  pixel13  pixel14  pixel15  pixel16  \
# 0     153      156      158      160      163      165      159      166
# 1     158      157      158      156      154      154      153      152
# 2     187      186      185      185      185      184      184      184
# 3     210      211      209      207      208      207      206      203
# 4     185      186      188      189      189      190      191      189
#
#    pixel17  pixel18  pixel19  pixel20  pixel21  pixel22  pixel23  pixel24  \
# 0      168      170      170      171      171      171      172      171
# 1      151      149      149      148      147      146      144      142
# 2      181      181      179      179      179      178      178      109
# 3      202      201      200      198      197      195      192      197
# 4      190      190      187      190      192      193      191      191
#
#    pixel25  pixel26  pixel27  pixel28  pixel29  pixel30  pixel31  pixel32  \
# 0      171      170      170      169      111      121      129      135
# 1      143      138       92      108      158      159      159      159
# 2       52       66       77       83      188      189      189      188
# 3      171       51       52       54      212      213      215      215
# 4      192      192      194      194      166      169      172      174
#
#    pixel33  pixel34  pixel35  pixel36  pixel37  pixel38  pixel39  pixel40  \
# 0      141      144      148      151      154      157      160      163
# 1      160      160      160      160      160      160      160      159
# 2      188      189      188      188      188      188      187      185
# 3      212      212      213      212      212      211      211      209
# 4      177      180      182      185      186      187      190      191
#
#    pixel41  pixel42  pixel43  pixel44  pixel45  pixel46  pixel47  pixel48  \
# 0      164      170      119      152      171      171      170      171
# 1      158      157      155      154      153      152      151      150
# 2      185      187      182      177      182      182      182      180
# 3      208      209      206      204      203      202      201      200
# 4      190      191      192      192      194      182      152      146
#
#    pixel49  pixel50  pixel51  pixel52  pixel53  pixel54  pixel55  pixel56  \
# 0      172      172      172      172      172      171      171      170
# 1      149      149      147      147      146      142      116      143
# 2      180      179      180      135       67       73       73       71
# 3      199      197      193      204      149       44       49       46
# 4      189      195      194      193      193      194      195      195
#
#    pixel57  pixel58  pixel59  pixel60  pixel61  pixel62  pixel63  pixel64  \
# 0      113      123      131      137      142      145      150      152
# 1      161      161      161      161      162      161      162      162
# 2      190      190      190      191      190      190      189      189
# 3      215      217      218      217      216      216      217      214
# 4      167      170      173      176      178      181      183      186
#
#    pixel65  pixel66  pixel67  pixel68  pixel69  pixel70  pixel71  pixel72  \
# 0      155      158      161      163      164      172      105      142
# 1      162      162      161      161      161      160      159      158
# 2      189      188      189      188      192      184      144      103
# 3      213      212      212      211      210      211      208      206
# 4      187      188      191      193      192      191      188      193
#
#    pixel73  pixel74  pixel75  pixel76  pixel77  pixel78  pixel79  pixel80  \
# 0      170      171      171      171      172      172      173      173
# 1      156      155      154      153      152      152      151      150
# 2      144      142      138      186      182      180      182      163
# 3      206      204      204      202      202      200      194      205
# 4      206      182      136       92      172      196      196      197
#
#    pixel81  pixel82  pixel83  pixel84  pixel85  pixel86  pixel87  pixel88  \
# 0      172      171      171      171      116      125      133      139
# 1      147      147      125      140      165      164      164      165
# 2       81       74       68       61      191      193      192      192
# 3      120       52       41       45      218      218      218      218
# 4      195      197      197      196      170      172      175      177
#
#    pixel89  pixel90  pixel91  pixel92  pixel93  pixel94  pixel95  pixel96  \
# 0      143      146      151      153      156      159      162      163
# 1      165      165      165      165      164      164      164      165
# 2      192      191      191      191      191      195      200      189
# 3      218      218      218      216      216      215      213      212
# 4      180      184      186      188      188      191      192      193
#
#    pixel97  pixel98  pixel99  pixel100  pixel101  pixel102  pixel103  \
# 0      167      167       95       144       171       172       172
# 1      163      163      162       161       159       159       158
# 2      165      127       98        71        85        94        86
# 3      213      211      209       208       209       208       208
# 4      197      183      153       153       196       178       135
#
#    pixel104  pixel105  pixel106  pixel107  pixel108  pixel109  pixel110  \
# 0       172       172       172       173       173       173       172
# 1       156       156       155       152       153       154       151
# 2       165       184       182       182       175        87        61
# 3       208       207       202       198       201        90        46
# 4        82       140       142       147       176       199       200
#
#    pixel111  pixel112  pixel113  pixel114  pixel115  pixel116  pixel117  \
# 0       172       171       117       126       134       140       145
# 1       124       126       166       167       166       167       167
# 2        51        56       192       193       194       193       193
# 3        44        34       219       218       220       221       220
# 4       199       197       171       173       176       179       182
#
#    pixel118  pixel119  pixel120  pixel121  pixel122  pixel123  pixel124  \
# 0       149       153       156       158       161       163       164
# 1       166       167       167       167       167       166       167
# 2       193       194       191       202       208       193       130
# 3       220       218       217       219       217       215       214
# 4       185       187       189       190       193       193       195
#
#    pixel125  pixel126  pixel127  pixel128  pixel129  pixel130  pixel131  \
# 0       175       156        87       154       172       173       173
# 1       165       165       164       163       162       162       161
# 2        95        78        69        62        69        72        69
# 3       214       211       201       187       186       182       179
# 4       214       190       144       117       178       173       132
#
#    pixel132  pixel133  pixel134  pixel135  pixel136  pixel137  pixel138  \
# 0       173       173       173       174       174       174       173
# 1       160       156       151       154       176       145       122
# 2        83       179       184       183       184       116        43
# 3       183       192       204       204       196        63        56
# 4        77       113       136       105       104       191       201
#
#    pixel139  pixel140  pixel141  pixel142  pixel143  pixel144  pixel145  \
# 0       172       172       119       128       136       142       146
# 1       144       100       168       169       168       169       169
# 2        38        56       193       193       194       195       195
# 3        49        36       221       221       221       222       222
# 4       200       199       172       174       177       181       184
#
#    pixel146  pixel147  pixel148  pixel149  pixel150  pixel151  pixel152  \
# 0       150       153       156       159       163       165       164
# 1       168       169       170       170       170       169       168
# 2       195       195       196       209       193       144        83
# 3       222       220       220       219       218       217       214
# 4       187       188       190       193       193       193       182
#
#    pixel153  pixel154  pixel155  pixel156  pixel157  pixel158  pixel159  \
# 0       184       148        89       164       172       174       174
# 1       167       166       167       165       162       159       159
# 2        58        61        62        52        60        65        66
# 3       213       212       198       193       186       178       164
# 4       187       191       163       121       172       166       119
#
#    pixel160  pixel161  pixel162  pixel163  pixel164  pixel165  pixel166  \
# 0       174       174       175       175       174       175       174
# 1       156       151       165       171       146        94       130
# 2        70       176       187       184       185       158        45
# 3       150       144       153       192       203        79        51
# 4        80       156       159       104        76       169       203
#
#    pixel167  pixel168  pixel169  pixel170  pixel171  pixel172  pixel173  \
# 0       173       173       122       130       138       143       147
# 1       159       111       171       171       170       171       171
# 2        35        45       194       194       195       196       196
# 3        35        33       224       222       223       223       223
# 4       200       200       173       175       179       182       185
#
#    pixel174  pixel175  pixel176  pixel177  pixel178  pixel179  pixel180  \
# 0       150       154       158       162       165       166       172
# 1       171       172       171       171       171       172       169
# 2       197       195       208       212       133        86        67
# 3       223       220       221       220       219       218       211
# 4       188       190       192       193       195       197       158
#
#    pixel181  pixel182  pixel183  pixel184  pixel185  pixel186  pixel187  \
# 0       181       128        94       170       173       175       174
# 1       169       170       166       165       160       157       170
# 2        52        52        60        61        63        73        91
# 3       208       214       197       176       200       165       145
# 4       120       132       165       118       164       183       117
#
#    pixel188  pixel189  pixel190  pixel191  pixel192  pixel193  pixel194  \
# 0       175       176       177       177       177       177       175
# 1       177       171       153       124        96       125       157
# 2       150       187       187       185       183       175       112
# 3       179       155       141       136       167        93        48
# 4       106       183       154       107        74       166       205
#
#    pixel195  pixel196  pixel197  pixel198  pixel199  pixel200  pixel201  \
# 0       175       174       122       132       139       145       149
# 1       155       146       172       172       172       173       173
# 2        83        55       195       196       195       198       198
# 3        33        32       225       225       225       224       223
# 4       202       202       174       177       180       183       187
#
#    pixel202  pixel203  pixel204  pixel205  pixel206  pixel207  pixel208  \
# 0       152       156       160       163       165       166       181
# 1       173       173       173       173       173       174       174
# 2       198       194       219       193       106        70        68
# 3       223       223       222       221       223       217       210
# 4       189       192       193       194       203       200       163
#
#    pixel209  pixel210  pixel211  pixel212  pixel213  pixel214  pixel215  \
# 0       172       103       113       175       176       178       178
# 1       171       167       169       175       171       164       165
# 2        64        60        63        71       150       174       187
# 3       210       214       155        82       119       104        81
# 4       126        97       146       116       159       191       122
#
#    pixel216  pixel217  pixel218  pixel219  pixel220  pixel221  pixel222  \
# 0       179       179       179       179       178       179       177
# 1       157       129       112       121       148       164       158
# 2       191       187       186       185       185       179       122
# 3       148       158       146       100        89        69        41
# 4       123       183       150       102        76       177       204
#
#    pixel223  pixel224  pixel225  pixel226  pixel227  pixel228  pixel229  \
# 0       175       174       125       134       141       147       150
# 1       155       152       175       174       174       174       175
# 2       145       140       195       197       198       199       200
# 3        38        29       225       226       226       225       226
# 4       203       203       175       179       181       185       188
#
#    pixel230  pixel231  pixel232  pixel233  pixel234  pixel235  pixel236  \
# 0       153       157       161       164       167       168       184
# 1       174       174       174       174       177       178       174
# 2       198       202       224       172       103        69        68
# 3       225       224       223       223       215       216       212
# 4       190       193       193       201       193       192       177
#
#    pixel237  pixel238  pixel239  pixel240  pixel241  pixel242  pixel243  \
# 0       179       116       126       165       176       179       180
# 1       170       178       182       171       154       127       120
# 2        66        60        94       163       195       193       190
# 3       175       151       110        71        63        61        61
# 4       137        95       124       125       104       119        88
#
#    pixel244  pixel245  pixel246  pixel247  pixel248  pixel249  pixel250  \
# 0       180       181       180       180       180       179       178
# 1       126       138       159       168       165       162       161
# 2       190       189       189       187       189       170        89
# 3        84       110       102        80        78        74        50
# 4       120       197       160        97        84       190       204
#
#    pixel251  pixel252  pixel253  pixel254  pixel255  pixel256  pixel257  \
# 0       177       176       128       135       142       148       152
# 1       158       157       176       176       176       176       177
# 2       169       171       198       200       200       200       200
# 3        48        42       226       226       226       226       226
# 4       204       205       177       180       183       187       189
#
#    pixel258  pixel259  pixel260  pixel261  pixel262  pixel263  pixel264  \
# 0       154       158       162       165       168       170       187
# 1       176       176       177       177       175       169       170
# 2       199       215       210       146        84        60        60
# 3       226       226       224       219       217       228       197
# 4       192       194       196       203       176       172       175
#
#    pixel265  pixel266  pixel267  pixel268  pixel269  pixel270  pixel271  \
# 0       180       156       161       124       143       179       178
# 1       178       169       158       163       139       119       155
# 2        61        66       168       201       193       192       191
# 3       126        81        71        70        62        51        60
# 4       135        92       101       129        77        27        64
#
#    pixel272  pixel273  pixel274  pixel275  pixel276  pixel277  pixel278  \
# 0       178       181       182       181       180       181       180
# 1       171       172       168       165       165       163       162
# 2       190       189       189       188       189       169       110
# 3        59        68        75        68        69        91       141
# 4       133       174       133        74        98       201       206
#
#    pixel279  pixel280  pixel281  pixel282  pixel283  pixel284  pixel285  \
# 0       179       179       129       136       144       150       153
# 1       160       158       177       177       177       178       177
# 2       182       143       199       200       201       201       200
# 3       135        60       227       228       228       227       227
# 4       206       206       178       182       185       187       189
#
#    pixel286  pixel287  pixel288  pixel289  pixel290  pixel291  pixel292  \
# 0       155       159       163       166       169       172       187
# 1       178       178       177       171       159       167       173
# 2       203       224       197       142        93        74        68
# 3       227       228       223       222       235       223       174
# 4       192       194       201       202       178       153       166
#
#    pixel293  pixel294  pixel295  pixel296  pixel297  pixel298  pixel299  \
# 0       184       153       102       117       110       175       169
# 1       157       142       163       152       133       167       177
# 2        59        70       177       199       195       194       193
# 3       127        96        60        58        65        85       137
# 4       135        87        86       121        88        27        69
#
#    pixel300  pixel301  pixel302  pixel303  pixel304  pixel305  pixel306  \
# 0       154       182       183       183       182       182       181
# 1       171       170       170       168       167       166       164
# 2       192       191       189       189       189       182       152
# 3       136       185       189       154       155       161       197
# 4       154       158       114        81       132       208       207
#
#    pixel307  pixel308  pixel309  pixel310  pixel311  pixel312  pixel313  \
# 0       181       179       131       138       145       150       155
# 1       161       159       178       178       179       179       180
# 2       130       102       201       201       202       202       200
# 3       182       104       228       229       229       230       228
# 4       208       208       178       181       184       187       190
#
#    pixel314  pixel315  pixel316  pixel317  pixel318  pixel319  pixel320  \
# 0       157       161       165       168       174       190       189
# 1       178       164       141       137       145       150       141
# 2       215       229       186       131        93        82        80
# 3       229       222       224       228       219       183       138
# 4       194       194       208       204       176       139       165
#
#    pixel321  pixel322  pixel323  pixel324  pixel325  pixel326  pixel327  \
# 0       175       146        94        97       113       151       158
# 1       134       150       154       151       177       181       175
# 2        68        81       195       196       195       195       195
# 3       109        93        69        62        60       171       233
# 4       131        88        79       112        95        63       127
#
#    pixel328  pixel329  pixel330  pixel331  pixel332  pixel333  pixel334  \
# 0       129       184       184       184       184       183       183
# 1       172       173       172       170       167       167       165
# 2       193       192       192       191       189       189       183
# 3       222       217       216       219       213       170       175
# 4       162       163       147       122       115       198       208
#
#    pixel335  pixel336  pixel337  pixel338  pixel339  pixel340  pixel341  \
# 0       182       180       131       139       146       151       155
# 1       163       161       180       179       180       182       180
# 2       131       130       201       202       202       203       202
# 3       120       121       230       231       231       230       232
# 4       209       209       178       181       185       188       191
#
#    pixel342  pixel343  pixel344  pixel345  pixel346  pixel347  pixel348  \
# 0       159       163       167       175       182       179       171
# 1       180       170       156       151       148       151       154
# 2       230       222       168       118        87        80        78
# 3       225       223       242       225       205       167       102
# 4       195       196       210       203       172       136       150
#
#    pixel349  pixel350  pixel351  pixel352  pixel353  pixel354  pixel355  \
# 0       159       114       102        89       121       136       136
# 1       153       153       148       153       147       140       171
# 2        75       110       202       197       197       196       195
# 3        82        81        73        62       143       221       215
# 4       127        89        76       131       118       118       188
#
#    pixel356  pixel357  pixel358  pixel359  pixel360  pixel361  pixel362  \
# 0        96       172       186       186       185       185       184
# 1       176       173       173       171       170       168       167
# 2       194       194       193       192       191       190       185
# 3       216       215       211       211       210       185       166
# 4       177       153       133       113        88       168       212
#
#    pixel363  pixel364  pixel365  pixel366  pixel367  pixel368  pixel369  \
# 0       182       181       131       140       147       154       157
# 1       165       163       182       181       181       182       179
# 2       169       161       202       202       203       202       207
# 3       108       168       231       232       232       234       227
# 4       210       210       180       182       185       189       192
#
#    pixel370  pixel371  pixel372  pixel373  pixel374  pixel375  pixel376  \
# 0       160       164       179       186       191       187       180
# 1       164       149       156       159       153       153       166
# 2       237       210       158       108        81        76        76
# 3       225       248       241       213       201       164       108
# 4       195       197       213       202       173       142       135
#
#    pixel377  pixel378  pixel379  pixel380  pixel381  pixel382  pixel383  \
# 0       157       100        88        84       108       111       126
# 1       173       169       169       163       151       105       141
# 2        75       116       205       197       198       198       196
# 3        68        73        72       177       229       219       218
# 4       128       109        76       151       146       168       194
#
#    pixel384  pixel385  pixel386  pixel387  pixel388  pixel389  pixel390  \
# 0        90       120       186       187       187       186       185
# 1       182       174       175       173       171       171       168
# 2       195       195       194       193       191       189       186
# 3       219       218       216       215       214       198       181
# 4       179       152       119        98        84       171       212
#
#    pixel391  pixel392  pixel393  pixel394  pixel395  pixel396  pixel397  \
# 0       184       182       133       141       149       155       158
# 1       166       165       183       183       183       182       171
# 2       174       182       202       203       205       200       218
# 3       156       152       233       233       235       230       226
# 4       210       211       181       182       186       189       193
#
#    pixel398  pixel399  pixel400  pixel401  pixel402  pixel403  pixel404  \
# 0       160       174       201       189       165       151       143
# 1       159       130       125       135       134       130       137
# 2       238       202       151       105        82        79        80
# 3       246       243       224       208       181       132       101
# 4       196       199       213       202       180       159       133
#
#    pixel405  pixel406  pixel407  pixel408  pixel409  pixel410  pixel411  \
# 0       146       120        87        78        87        76       108
# 1       146       147       164       165       147       103       151
# 2        75       129       206       198       199       198       197
# 3        82        58       131       237       219       222       222
# 4       116       111        70       149       183       204       193
#
#    pixel412  pixel413  pixel414  pixel415  pixel416  pixel417  pixel418  \
# 0        98        96       181       188       187       186       186
# 1       182       176       176       175       173       172       170
# 2       196       196       194       193       192       190       189
# 3       220       217       216       216       215       208       182
# 4       170       143       110        89        93       192       213
#
#    pixel419  pixel420  pixel421  pixel422  pixel423  pixel424  pixel425  \
# 0       185       183       133       141       150       156       160
# 1       167       166       184       185       185       176       174
# 2       184       166       204       204       207       202       234
# 3       184       167       235       236       234       226       250
# 4       211       211       181       184       187       190       194
#
#    pixel426  pixel427  pixel428  pixel429  pixel430  pixel431  pixel432  \
# 0       161       179       197       174       135        99        72
# 1       163       147       145       142       141       141       133
# 2       228       186       141        97        80        80        79
# 3       250       230       218       201       162       124        93
# 4       196       200       214       203       183       166       149
#
#    pixel433  pixel434  pixel435  pixel436  pixel437  pixel438  pixel439  \
# 0        95       134        97        72        74        68       116
# 1       125       125       135       135       112       105       181
# 2        68       136       209       198       199       199       198
# 3        62        82       214       228       223       224       225
# 4       119       104       109       188       205       209       189
#
#    pixel440  pixel441  pixel442  pixel443  pixel444  pixel445  pixel446  \
# 0       105       108       187       189       187       187       186
# 1       179       176       177       175       174       173       171
# 2       197       198       197       196       192       192       191
# 3       223       219       217       216       215       214       196
# 4       160       133       102        85       108       206       213
#
#    pixel447  pixel448  pixel449  pixel450  pixel451  pixel452  pixel453  \
# 0       186       185       134       143       151       156       161
# 1       169       166       185       186       182       170       161
# 2       190       158       206       206       202       215       240
# 3       174       181       235       237       233       248       255
# 4       213       212       182       185       188       191       194
#
#    pixel454  pixel455  pixel456  pixel457  pixel458  pixel459  pixel460  \
# 0       163       179       194       156       110        74        42
# 1       132       125       134       130       144       157       159
# 2       217       174       130        91        78        74        71
# 3       244       222       209       182       148       116        82
# 4       196       200       211       203       185       171       164
#
#    pixel461  pixel462  pixel463  pixel464  pixel465  pixel466  pixel467  \
# 0        52       139        94        67        75        75       118
# 1       152       141       132       121        72       142       176
# 2        70        83       192       203       200       200       201
# 3        50       126       246       222       226       226       226
# 4       140       122       127       187       206       201       173
#
#    pixel468  pixel469  pixel470  pixel471  pixel472  pixel473  pixel474  \
# 0       106       129       189       191       190       188       188
# 1       175       182       177       177       177       175       172
# 2       200       191       177       164       151       144       164
# 3       225       219       219       222       213       213       217
# 4       142       119        95        85       147       214       214
#
#    pixel475  pixel476  pixel477  pixel478  pixel479  pixel480  pixel481  \
# 0       187       186       135       144       152       158       163
# 1       169       168       186       186       173       168       159
# 2       190       187       206       207       199       229       234
# 3       180       122       237       234       245       255       252
# 4       215       214       181       185       187       190       193
#
#    pixel482  pixel483  pixel484  pixel485  pixel486  pixel487  pixel488  \
# 0       163       177       193       161       122        84        43
# 1       128       115       119       109       111       140       154
# 2       204       160       119        89        75        66        69
# 3       232       212       198       171       129        98        66
# 4       196       199       204       200       190       176       169
#
#    pixel489  pixel490  pixel491  pixel492  pixel493  pixel494  pixel495  \
# 0        71       134        81        57        71        88       112
# 1       156       153       140       118        64        67       121
# 2        73        69       121       212       204       203       189
# 3        66        68       202       234       224       226       226
# 4       148       127       124       183       205       189       157
#
#    pixel496  pixel497  pixel498  pixel499  pixel500  pixel501  pixel502  \
# 0        98       157       193       193       192       190       190
# 1       148       160       181       177       177       176       173
# 2       164       151       151       146       138       119        91
# 3       223       226       216       182       162       151       187
# 4       128       108        89       103       196       214       214
#
#    pixel503  pixel504  pixel505  pixel506  pixel507  pixel508  pixel509  \
# 0       189       188       136       144       152       158       162
# 1       169       177       189       178       165       173       163
# 2       182       191       208       205       206       238       225
# 3       218        84       233       244       255       247       238
# 4       216       215       181       184       187       191       193
#
#    pixel510  pixel511  pixel512  pixel513  pixel514  pixel515  pixel516  \
# 0       163       176       192       164       128        98        62
# 1       138       128       128       124       117       111       106
# 2       190       149       113        89        70        62        68
# 3       223       202       186       155       110        84        61
# 4       196       197       200       199       192       176       171
#
#    pixel517  pixel518  pixel519  pixel520  pixel521  pixel522  pixel523  \
# 0        60       100        71        76        96       101       105
# 1       118       139       133        93        40        53       109
# 2        73        75        74       156       179       161       147
# 3        73        64        85       225       227       223       228
# 4       154       131       131       173       199       174       145
#
#    pixel524  pixel525  pixel526  pixel527  pixel528  pixel529  pixel530  \
# 0        95       174       195       194       194       194       193
# 1       146       119       174       179       176       175       174
# 2       147       155       151       133       112       117       123
# 3       237       206       145       144       164       111       139
# 4       119        99        82       143       214       213       214
#
#    pixel531  pixel532  pixel533  pixel534  pixel535  pixel536  pixel537  \
# 0       191       190       137       145       152       159       164
# 1       177       168       186       168       169       169       155
# 2       184       189       207       198       224       237       218
# 3       227       163       241       255       252       237       225
# 4       215       214       181       184       187       191       194
#
#    pixel538  pixel539  pixel540  pixel541  pixel542  pixel543  pixel544  \
# 0       165       178       191       164       135       113        82
# 1       151       145       139       135       130       121       112
# 2       181       139       107        85        63        62        75
# 3       209       190       173       135       102        77        76
# 4       196       198       200       202       194       177       167
#
#    pixel545  pixel546  pixel547  pixel548  pixel549  pixel550  pixel551  \
# 0        59        87        98       111       120       108        97
# 1       104        95       101        61        39        71        99
# 2        80        82        83        80       111       136       157
# 3        88        92        67       152       245       231       206
# 4       151       131       133       168       176       153       132
#
#    pixel552  pixel553  pixel554  pixel555  pixel556  pixel557  pixel558  \
# 0       108       190       196       195       195       194       193
# 1       114       103       177       180       178       178       176
# 2       158       140       109       103       154       190       192
# 3       170       130       138       160       121       128       210
# 4       109        92        89       181       213       213       213
#
#    pixel559  pixel560  pixel561  pixel562  pixel563  pixel564  pixel565  \
# 0       193       192       139       146       154       160       164
# 1       130       171       168       166       163       163       158
# 2       190       190       199       209       238       232       209
# 3       211       215       228       255       249       225       216
# 4       213       214       182       185       188       192       194
#
#    pixel566  pixel567  pixel568  pixel569  pixel570  pixel571  pixel572  \
# 0       165       175       186       163       139       112        85
# 1       149       139       137       138       132       122       116
# 2       173       137       100        80        58        73        90
# 3       198       185       162       123       100        82        92
# 4       196       198       200       203       191       172       162
#
#    pixel573  pixel574  pixel575  pixel576  pixel577  pixel578  pixel579  \
# 0        67       102       126       133       126       105       104
# 1       107        72        66        57        55        63        77
# 2        97       102        99       100       117       139       145
# 3       100        98        94        81       147       144       106
# 4       142       124       137       161       150       137       117
#
#    pixel580  pixel581  pixel582  pixel583  pixel584  pixel585  pixel586  \
# 0       176       197       198       197       196       195       195
# 1        95       155       189       186       177       158       115
# 2       122        95        94       175       199       195       193
# 3        94       104       144       114       106       220       215
# 4        98        87       123       207       213       214       214
#
#    pixel587  pixel588  pixel589  pixel590  pixel591  pixel592  pixel593  \
# 0       194       193       138       147       155       161       165
# 1        86       159       162       162       159       168       170
# 2       193       190       200       233       237       224       201
# 3       213       210        90       146       207       193       183
# 4       214       214       184       186       189       192       194
#
#    pixel594  pixel595  pixel596  pixel597  pixel598  pixel599  pixel600  \
# 0       167       172       186       163       137       107        87
# 1       135       106        97        82        83       103       111
# 2       167       129        96        80        61        86        98
# 3       193       175       148       120        94        83        99
# 4       196       198       197       203       182       165       151
#
#    pixel601  pixel602  pixel603  pixel604  pixel605  pixel606  pixel607  \
# 0        76       106       122       125       117        96       156
# 1        87        68        65        54        89       144       155
# 2       106       112       107       107       114       115       103
# 3       102        99        97        89        78        87        98
# 4       129       123       143       151       134       127       107
#
#    pixel608  pixel609  pixel610  pixel611  pixel612  pixel613  pixel614  \
# 0       199       199       200       198       196       196       195
# 1       173       182       157       165       147       109       134
# 2       115       153       187       199       195       194       192
# 3       122       111       117        61       177       226       215
# 4        92        94       177       214       214       214       214
#
#    pixel615  pixel616  pixel617  pixel618  pixel619  pixel620  pixel621  \
# 0       195       194       139       148       156       163       166
# 1       153       145       165       156       162       169       151
# 2       190       190       228       236       226       214       194
# 3       215       211        74        63        80       119       134
# 4       215       215       184       185       189       192       195
#
#    pixel622  pixel623  pixel624  pixel625  pixel626  pixel627  pixel628  \
# 0       168       172       180       158       131       108        99
# 1       101        73        55        54        65        94        98
# 2       160       120        92        78        70        95       104
# 3       134       136       117        90        77        82        97
# 4       197       194       201       202       178       166       147
#
#    pixel629  pixel630  pixel631  pixel632  pixel633  pixel634  pixel635  \
# 0        86       108       118       116       103       107       191
# 1        71        64        53       114       189       183       177
# 2       107       111       103        94        83       100       158
# 3        97        97        93        89        86       106       109
# 4       132       134       150       145       130       116       100
#
#    pixel636  pixel637  pixel638  pixel639  pixel640  pixel641  pixel642  \
# 0       202       201       200       200       200       199       197
# 1       159       147       142       149       126       160       172
# 2       197       202       200       197       195       194       192
# 3       117       102        63        91       224       218       218
# 4        88       145       209       214       214       215       215
#
#    pixel643  pixel644  pixel645  pixel646  pixel647  pixel648  pixel649  \
# 0       198       196       140       149       157       164       168
# 1       130        92       164       169       171       155       114
# 2       190       189       227       228       220       206       183
# 3       215       212        71        72        65        65        65
# 4       216       216       184       186       189       193       196
#
#    pixel650  pixel651  pixel652  pixel653  pixel654  pixel655  pixel656  \
# 0       167       177       178       155       131       118       105
# 1        82        69        52        62        75        91        82
# 2       148       106        90        78        83       103       110
# 3        71        75        57        54        66        70        83
# 4       198       194       209       207       184       175       148
#
#    pixel657  pixel658  pixel659  pixel660  pixel661  pixel662  pixel663  \
# 0        87       100       106       100        96       164       202
# 1        69        62       139       191       154       120       118
# 2       106        95        85        77       121       189       205
# 3        88        88        84        89        90        95        87
# 4       137       148       153       133       122       100        87
#
#    pixel664  pixel665  pixel666  pixel667  pixel668  pixel669  pixel670  \
# 0       202       202       202       202       201       200       199
# 1       137       147       163       145       159       180       126
# 2       202       200       201       198       196       195       192
# 3        77        89       144       210       224       219       219
# 4       110       195       215       215       214       215       215
#
#    pixel671  pixel672  pixel673  pixel674  pixel675  pixel676  pixel677  \
# 0       199       198       140       150       157       165       167
# 1        87        88       162       170       162       135        98
# 2       190       190       219       216       204       182       160
# 3       217       214        67        66        63        65        58
# 4       216       216       180       184       187       191       194
#
#    pixel678  pixel679  pixel680  pixel681  pixel682  pixel683  pixel684  \
# 0       170       181       175       152       130       115        98
# 1        79        66        58        67        68        66        64
# 2       127        96        87        77        89       100       104
# 3        29        34        43        46        53        52        66
# 4       196       192       206       202       186       181       152
#
#    pixel685  pixel686  pixel687  pixel688  pixel689  pixel690  pixel691  \
# 0        82        85        90        99       165       202       203
# 1        79       146       189       148       132       136       133
# 2        94        72       103       174       204       205       203
# 3        79        74        67        64        57        70       115
# 4       146       155       143       121       106        88        82
#
#    pixel692  pixel693  pixel694  pixel695  pixel696  pixel697  pixel698  \
# 0       204       203       203       202       202       201       201
# 1       144       154       184       139       130       121        93
# 2       201       200       201       199       197       195       193
# 3       167       216       236       228       223       221       220
# 4       161       213       214       216       215       216       216
#
#    pixel699  pixel700  pixel701  pixel702  pixel703  pixel704  pixel705  \
# 0       200       200       142       150       159       165       170
# 1       102       100       162       159       145       112        85
# 2       192       191       212       198       175       158       136
# 3       219       217        65        62        58        55        63
# 4       216       217       130       134       139       143       147
#
#    pixel706  pixel707  pixel708  pixel709  pixel710  pixel711  pixel712  \
# 0       191       173       157       144       119        97        84
# 1        75        68        65        64        62        79       123
# 2       103        85        76        81        89        92        88
# 3        44        11        22        24        28        34        49
# 4       146       173       200       187       178       174       150
#
#    pixel713  pixel714  pixel715  pixel716  pixel717  pixel718  pixel719  \
# 0        79        79        91       172       202       203       203
# 1       192       198       183       126        81       123       137
# 2        69       108       195       208       204       203       203
# 3        46        62        95       109       141       202       237
# 4       143       149       138       108        94        81        94
#
#    pixel720  pixel721  pixel722  pixel723  pixel724  pixel725  pixel726  \
# 0       205       204       204       204       203       202       202
# 1       129       154       217       133        87        87        91
# 2       201       200       200       199       196       195       195
# 3       240       231       226       226       224       222       220
# 4       178       198       201       204       206       208       209
#
#    pixel727  pixel728  pixel729  pixel730  pixel731  pixel732  pixel733  \
# 0       201       200       142       151       160       165       188
# 1       101        94       153       139       115        89        77
# 2       193       192       202       179       152       140       118
# 3       219       217        63        56        52        52        59
# 4       211       211        99       101       100       100       100
#
#    pixel734  pixel735  pixel736  pixel737  pixel738  pixel739  pixel740  \
# 0       190       187       150       119       109        85        79
# 1        72        65        77       106       137       174       185
# 2        85        75        78        82        77        75        87
# 3        56        17        16        20        17        17        14
# 4        97       163       200       179       161       150       138
#
#    pixel741  pixel742  pixel743  pixel744  pixel745  pixel746  pixel747  \
# 0        79        78       137       203       205       206       206
# 1       146       121       111       112       100        78       120
# 2       142       203       208       205       203       204       203
# 3       120       217       237       244       247       242       233
# 4       138       151       132        97        90        77        88
#
#    pixel748  pixel749  pixel750  pixel751  pixel752  pixel753  pixel754  \
# 0       207       207       206       206       204       205       204
# 1       157       168       107        99       121       133        97
# 2       201       200       200       199       198       196       195
# 3       231       230       229       227       225       223       221
# 4       117       123       127       129       134       145       152
#
#    pixel755  pixel756  pixel757  pixel758  pixel759  pixel760  pixel761  \
# 0       203       202       142       151       160       172       196
# 1        95       120       135       116        95        79        69
# 2       194       193       198       166       132       114        89
# 3       220       216        58        51        49        50        57
# 4       156       179       105       106       105       104       104
#
#    pixel762  pixel763  pixel764  pixel765  pixel766  pixel767  pixel768  \
# 0       188       188       190       135        96        86        77
# 1        86       139       173       200       185       175       198
# 2        74        79        77        74        78       132       188
# 3        60        17        15        18        17        19         1
# 4       104       175       199       178       152       136       130
#
#    pixel769  pixel770  pixel771  pixel772  pixel773  pixel774  pixel775  \
# 0        77        79       176       205       207       207       207
# 1       124       118        94       140       133        84        69
# 2       210       209       206       205       204       203       202
# 3       159       255       237       239       237       236       235
# 4       136       150       118        92        85        76        92
#
#    pixel776  pixel777  pixel778  pixel779  pixel780  pixel781  pixel782  \
# 0       207       207       207       206       206       206       204
# 1       149       128        87        94       163       175       103
# 2       201       200       199       198       199       198       195
# 3       234       233       231       230       226       225       222
# 4       105       105       108       133       163       157       163
#
#    pixel783  pixel784
# 0       203       202
# 1       135       149
# 2       194       195
# 3       229       163
# 4       164       179

# %%
test_base.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      6     149     149     150     150     150     151     151     150
# 1      5     126     128     131     132     133     134     135     135
# 2     10      85      88      92      96     105     123     135     143
# 3      0     203     205     207     206     207     209     210     209
# 4      3     188     191     193     195     199     201     202     203
#
#    pixel9  pixel10  pixel11  pixel12  pixel13  pixel14  pixel15  pixel16  \
# 0     151      152      152      152      152      152      153      153
# 1     136      138      137      137      138      138      139      137
# 2     147      152      157      163      168      171      182      172
# 3     210      209      208      207      207      209      208      210
# 4     203      203      204      204      204      203      202      198
#
#    pixel17  pixel18  pixel19  pixel20  pixel21  pixel22  pixel23  pixel24  \
# 0      151      152      152      153      152      152      151      151
# 1      142      140      138      139      137      137      136      135
# 2      175      185      183      184      185      185      185      183
# 3      210      207      209      209      208      209      210      209
# 4      216      217      135      181      200      195      194      193
#
#    pixel25  pixel26  pixel27  pixel28  pixel29  pixel30  pixel31  pixel32  \
# 0      150      150      150      149      150      150      150      152
# 1      134      133      134      132      129      132      134      135
# 2      183      182      181      178       86       88       93       96
# 3      207      208      209      207      206      208      209      208
# 4      190      189      187      185      190      194      196      197
#
#    pixel33  pixel34  pixel35  pixel36  pixel37  pixel38  pixel39  pixel40  \
# 0      152      151      152      152      152      152      152      153
# 1      135      137      139      139      139      140      141      141
# 2      108      125      137      145      149      154      160      166
# 3      208      210      211      210      211      209      209      210
# 4      200      202      204      206      207      207      206      205
#
#    pixel41  pixel42  pixel43  pixel44  pixel45  pixel46  pixel47  pixel48  \
# 0      154      153      154      154      153      154      153      154
# 1      142      143      142      142      116      138      141      140
# 2      170      174      215      154      142      190      184      184
# 3      211      211      209      208      211      215      210      212
# 4      206      206      205      200      220      206      122      155
#
#    pixel49  pixel50  pixel51  pixel52  pixel53  pixel54  pixel55  pixel56  \
# 0      153      153      152      152      152      151      150      151
# 1      141      140      139      138      137      136      136      134
# 2      186      187      185      184      183      183      181      179
# 3      212      211      211      210      210      211      210      210
# 4      207      196      195      195      193      191      188      187
#
#    pixel57  pixel58  pixel59  pixel60  pixel61  pixel62  pixel63  pixel64  \
# 0      150      151      151      152      152      152      153      153
# 1      133      135      138      139      139      141      142      143
# 2       86       89       93       98      110      127      138      147
# 3      209      209      210      211      210      210      212      212
# 4      192      195      198      199      203      205      206      208
#
#    pixel65  pixel66  pixel67  pixel68  pixel69  pixel70  pixel71  pixel72  \
# 0      152      152      152      153      154      154      155      155
# 1      142      143      145      145      143      145      145      158
# 2      150      155      162      169      171      183      214      162
# 3      211      212      210      210      212      211      223      208
# 4      209      209      209      208      208      207      207      202
#
#    pixel73  pixel74  pixel75  pixel76  pixel77  pixel78  pixel79  pixel80  \
# 0      154      154      155      155      155      155      154      153
# 1       94      118      151      143      144      144      142      141
# 2      123      187      188      187      189      188      187      186
# 3      162      176      219      204      206      217      216      214
# 4      219      195      123      146      209      197      197      197
#
#    pixel81  pixel82  pixel83  pixel84  pixel85  pixel86  pixel87  pixel88  \
# 0      153      151      151      152      150      151      151      152
# 1      141      140      139      138      137      139      142      142
# 2      185      185      183      181       88       91       95       99
# 3      212      209      211      212      209      210      211      213
# 4      195      191      190      188      193      197      200      201
#
#    pixel89  pixel90  pixel91  pixel92  pixel93  pixel94  pixel95  pixel96  \
# 0      152      152      154      154      154      154      154      153
# 1      142      144      146      146      146      147      147      147
# 2      111      128      141      149      152      157      165      171
# 3      215      213      211      213      213      211      216      216
# 4      204      207      209      210      211      211      211      210
#
#    pixel97  pixel98  pixel99  pixel100  pixel101  pixel102  pixel103  \
# 0      154      155      156       157       157       156       155
# 1      148      117      128       168       101        98       157
# 2      175      184      215       182       116       179       193
# 3      179      167      228       202       161       129       132
# 4      210      209      208       205       219       197       123
#
#    pixel104  pixel105  pixel106  pixel107  pixel108  pixel109  pixel110  \
# 0       156       155       154       154       155       152       154
# 1       146       147       146       146       145       144       143
# 2       190       191       190       189       186       187       186
# 3       155       141       187       210       159       197       217
# 4       142       209       199       200       197       195       194
#
#    pixel111  pixel112  pixel113  pixel114  pixel115  pixel116  pixel117  \
# 0       153       153       151       152       152       152       154
# 1       142       141       140       142       145       146       147
# 2       186       183        88        92        96        99       113
# 3       211       211       210       211       211       213       214
# 4       192       190       196       199       202       204       206
#
#    pixel118  pixel119  pixel120  pixel121  pixel122  pixel123  pixel124  \
# 0       154       154       154       154       155       157       156
# 1       148       149       149       149       151       151       149
# 2       130       144       151       154       160       167       173
# 3       213       213       214       215       216       245       228
# 4       209       211       212       213       213       213       212
#
#    pixel125  pixel126  pixel127  pixel128  pixel129  pixel130  pixel131  \
# 0       156       156       154       150       146       147       146
# 1       161       114        99       174        99        84       162
# 2       180       181       215       206       128       169       198
# 3       181       138       184       210       175       160        76
# 4       212       212       210       206       223       221       143
#
#    pixel132  pixel133  pixel134  pixel135  pixel136  pixel137  pixel138  \
# 0       147       143       137       126       126       142       139
# 1       149       151       149       148       147       146       146
# 2       192       192       192       191       191       191       188
# 3       133       143       118       180       126       170       225
# 4       135       207       202       201       200       197       196
#
#    pixel139  pixel140  pixel141  pixel142  pixel143  pixel144  pixel145  \
# 0       152       154       152       153       153       154       154
# 1       145       144       143       145       149       150       150
# 2       187       186        89        93        98       101       116
# 3       211       214       210       212       213       213       213
# 4       194       191       199       201       203       207       209
#
#    pixel146  pixel147  pixel148  pixel149  pixel150  pixel151  pixel152  \
# 0       155       154       155       155       154       153       150
# 1       151       153       153       154       153       154       152
# 2       133       145       152       155       162       169       175
# 3       215       213       221       198       181       245       225
# 4       211       213       215       216       216       216       216
#
#    pixel153  pixel154  pixel155  pixel156  pixel157  pixel158  pixel159  \
# 0       144       143       145       139       142       144       157
# 1       167       126        88       169        99        87       164
# 2       181       182       226       217       138       157       203
# 3       192       156       176       234       181       168        95
# 4       215       213       212       207       229       225       143
#
#    pixel160  pixel161  pixel162  pixel163  pixel164  pixel165  pixel166  \
# 0       157       147       139       128       119       130       113
# 1       152       153       152       151       150       149       148
# 2       193       194       195       193       193       193       191
# 3       158       159       121       145       134       161       228
# 4       127       206       203       202       201       198       196
#
#    pixel167  pixel168  pixel169  pixel170  pixel171  pixel172  pixel173  \
# 0       147       156       151       153       153       155       155
# 1       148       147       145       147       151       152       153
# 2       189       187        91        94        99       102       118
# 3       214       216       211       213       214       215       215
# 4       195       193       199       203       206       209       212
#
#    pixel174  pixel175  pixel176  pixel177  pixel178  pixel179  pixel180  \
# 0       156       155       152       145       139       141       141
# 1       155       155       155       151       154       158       155
# 2       135       147       154       157       164       172       179
# 3       215       218       252       199       142       192       244
# 4       214       216       217       218       218       218       217
#
#    pixel181  pixel182  pixel183  pixel184  pixel185  pixel186  pixel187  \
# 0       141       153       153       143       135       137       139
# 1       170       130        79       166       111        93       166
# 2       185       183       225       213       148       146       205
# 3       200       166       160       249       199       175       102
# 4       216       216       215       208       234       215       133
#
#    pixel188  pixel189  pixel190  pixel191  pixel192  pixel193  pixel194  \
# 0       133       121       107       101       104       110       127
# 1       156       157       156       155       153       152       152
# 2       196       197       198       196       196       195       193
# 3       176       164       113       111       137       131       232
# 4       125       209       205       203       202       200       197
#
#    pixel195  pixel196  pixel197  pixel198  pixel199  pixel200  pixel201  \
# 0       157       156       151       152       153       155       155
# 1       152       150       149       150       153       155       155
# 2       191       190        91        95       100       101       118
# 3       213       217       213       214       214       215       217
# 4       196       195       201       205       209       211       215
#
#    pixel202  pixel203  pixel204  pixel205  pixel206  pixel207  pixel208  \
# 0       154       151       146       139       131       130       134
# 1       158       157       163       129       120       166       156
# 2       136       149       156       159       167       174       180
# 3       211       235       246       207       174       164       250
# 4       217       219       220       221       220       220       220
#
#    pixel209  pixel210  pixel211  pixel212  pixel213  pixel214  pixel215  \
# 0       137       132       125       111       101        94        95
# 1       171       140        82       162       102        97       168
# 2       186       184       228       223       148       128       205
# 3       211       166       144       248       204       171        96
# 4       218       218       217       210       234       214       136
#
#    pixel216  pixel217  pixel218  pixel219  pixel220  pixel221  pixel222  \
# 0       105       113       122       133       145       153       157
# 1       158       160       158       162       160       154       154
# 2       199       200       200       199       197       196       196
# 3       179       161        98        94       152        85       209
# 4       127       212       208       206       204       202       199
#
#    pixel223  pixel224  pixel225  pixel226  pixel227  pixel228  pixel229  \
# 0       156       156       152       152       154       152       151
# 1       154       152       151       152       156       158       159
# 2       193       193        91        94        99       102       120
# 3       221       217       214       216       216       216       214
# 4       197       196       203       207       211       215       217
#
#    pixel230  pixel231  pixel232  pixel233  pixel234  pixel235  pixel236  \
# 0       150       149       149       139       122       104        98
# 1       159       158       164       139        91       165       159
# 2       139       152       157       161       167       176       184
# 3       233       229       227       222       190       140       226
# 4       218       221       222       223       223       223       223
#
#    pixel237  pixel238  pixel239  pixel240  pixel241  pixel242  pixel243  \
# 0        92        82        81        81        85       114       145
# 1       174       144        71       156        96       100       171
# 2       187       186       232       232       161       112       201
# 3       220       160       123       239       206       155        77
# 4       222       220       219       215       245       211       138
#
#    pixel244  pixel245  pixel246  pixel247  pixel248  pixel249  pixel250  \
# 0       157       160       162       161       159       157       156
# 1       161       161       158       128       145       162       156
# 2       202       201       201       200       199       199       198
# 3       138       144        88        82       161        76       141
# 4       127       212       209       208       206       204       201
#
#    pixel251  pixel252  pixel253  pixel254  pixel255  pixel256  pixel257  \
# 0       156       156       151       151       150       146       145
# 1       155       155       152       155       159       160       161
# 2       195       195        92        95       100       104       123
# 3       233       216       215       216       217       216       217
# 4       200       197       205       209       213       216       218
#
#    pixel258  pixel259  pixel260  pixel261  pixel262  pixel263  pixel264  \
# 0       147       148       147       145       132        97        71
# 1       161       160       168       158        76       159       164
# 2       138       152       163       165       177       209       150
# 3       237       194       217       235       197       131       193
# 4       221       223       225       225       226       225       225
#
#    pixel265  pixel266  pixel267  pixel268  pixel269  pixel270  pixel271  \
# 0        62        66        88       116       145       162       160
# 1       172       142        63       155       117       100       174
# 2       170       194       223       211       162       101       187
# 3       228       158       100       198       194       137        69
# 4       224       221       222       211       196       171       117
#
#    pixel272  pixel273  pixel274  pixel275  pixel276  pixel277  pixel278  \
# 0       159       157       155       156       157       157       156
# 1       159       164       164       126       103       162       161
# 2       208       203       203       203       202       201       200
# 3       105       127        78        84       166        89       111
# 4       125       218       209       209       208       205       202
#
#    pixel279  pixel280  pixel281  pixel282  pixel283  pixel284  pixel285  \
# 0       155       155       151       145       144       145       147
# 1       158       157       153       157       160       162       162
# 2       198       198        92        97       101       106       120
# 3       231       218       217       217       219       214       230
# 4       199       197       206       211       215       218       221
#
#    pixel286  pixel287  pixel288  pixel289  pixel290  pixel291  pixel292  \
# 0       145       147       150       150       124        92        68
# 1       162       164       167       158        78       158       167
# 2       159       193       150       116       161       193       103
# 3       230       180       192       229       195       129       156
# 4       224       226       227       228       228       228       227
#
#    pixel293  pixel294  pixel295  pixel296  pixel297  pixel298  pixel299  \
# 0        63        67        86       159       163       155       158
# 1       167       156        73       133       129       102       172
# 2       127       204       214       191       148        91       168
# 3       217       151        87       153       177       128        78
# 4       225       228       248       205       135       103        83
#
#    pixel300  pixel301  pixel302  pixel303  pixel304  pixel305  pixel306  \
# 0       157       156       156       157       156       156       156
# 1       157       148       130       156       132       129       163
# 2       214       205       206       205       203       203       203
# 3        88       114        64       102       178       106       115
# 4       146       224       210       211       210       206       204
#
#    pixel307  pixel308  pixel309  pixel310  pixel311  pixel312  pixel313  \
# 0       155       154       143       144       145       145       143
# 1       161       159       157       159       162       164       164
# 2       201       200        93        97       101       108       119
# 3       233       220       217       218       218       216       230
# 4       201       199       208       213       217       220       224
#
#    pixel314  pixel315  pixel316  pixel317  pixel318  pixel319  pixel320  \
# 0       147       152       152       128        90        79        68
# 1       165       166       167       173        89       139       172
# 2       176       191       111        86        99       141       104
# 3       223       188       176       204       173       118       121
# 4       226       227       229       230       230       229       226
#
#    pixel321  pixel322  pixel323  pixel324  pixel325  pixel326  pixel327  \
# 0        64        70        67        84       147       164       157
# 1       162       163        79        98       132       111       170
# 2        66       164       205       167       157        95       160
# 3       191       141        81       110       168       123        74
# 4       224       206       203       208       162       122        67
#
#    pixel328  pixel329  pixel330  pixel331  pixel332  pixel333  pixel334  \
# 0       158       157       157       157       156       157       156
# 1       160       142        54       125       150       102       150
# 2       218       206       207       207       205       204       204
# 3        88       117        74       157       195       120       119
# 4       188       226       212       214       212       209       206
#
#    pixel335  pixel336  pixel337  pixel338  pixel339  pixel340  pixel341  \
# 0       156       155       145       146       143       145       145
# 1       167       162       159       161       166       165       167
# 2       202       202        93        98       100       108       126
# 3       234       222       213       216       215       221       232
# 4       203       201       210       214       218       222       225
#
#    pixel342  pixel343  pixel344  pixel345  pixel346  pixel347  pixel348  \
# 0       150       149       149       139       118        85        62
# 1       167       167       168       178       118       112       175
# 2       150       151       113       100        90       128       113
# 3       209       174       140       183       167       113        96
# 4       227       230       230       232       232       226       241
#
#    pixel349  pixel350  pixel351  pixel352  pixel353  pixel354  pixel355  \
# 0        62        75        73        62        67       140       164
# 1       164       167        82        91       129       110       160
# 2        71        72       128       133       166       118       136
# 3       178       139        71        82       166       122        64
# 4       241       173       112       174       233       151       109
#
#    pixel356  pixel357  pixel358  pixel359  pixel360  pixel361  pixel362  \
# 0       157       158       158       158       158       157       157
# 1       156       130        96       157       130       106       169
# 2       220       207       208       208       208       206       205
# 3       111       127        97       196       189       122       128
# 4       168       210       221       216       213       210       208
#
#    pixel363  pixel364  pixel365  pixel366  pixel367  pixel368  pixel369  \
# 0       156       156       150       147       144       147       149
# 1       165       164       159       162       166       167       168
# 2       205       203        94        98       101       109       128
# 3       235       221       213       215       215       215       246
# 4       205       203       210       216       219       223       226
#
#    pixel370  pixel371  pixel372  pixel373  pixel374  pixel375  pixel376  \
# 0       148       149       158       158       136        94        63
# 1       168       170       169       164       168       132       141
# 2       145       159       161       154       142       144       119
# 3       229       187       129       145       170       101        83
# 4       229       231       233       228       236       199       159
#
#    pixel377  pixel378  pixel379  pixel380  pixel381  pixel382  pixel383  \
# 0        58        69        85        82        67        70       156
# 1       162       153       103       113       117        96       133
# 2       101        70        72        93       130       124       105
# 3       169       144        70        75       173       120       130
# 4       215       180       130       150       240       144       123
#
#    pixel384  pixel385  pixel386  pixel387  pixel388  pixel389  pixel390  \
# 0       160       159       160       159       158       157       156
# 1       143       107       147       172        99       139       174
# 2       209       211       210       210       209       208       208
# 3       197       163       118       184       196       122       138
# 4       104       137       161       215       215       211       210
#
#    pixel391  pixel392  pixel393  pixel394  pixel395  pixel396  pixel397  \
# 0       156       156       147       148       147       145       148
# 1       165       166       161       164       167       170       171
# 2       207       205        95        98       101       109       129
# 3       234       220       215       217       216       217       244
# 4       208       205       211       217       221       224       228
#
#    pixel398  pixel399  pixel400  pixel401  pixel402  pixel403  pixel404  \
# 0       152       151       160       153       119        86        66
# 1       171       170       173       160       173       162       129
# 2       147       162       169       181       186       132       138
# 3       231       192       146       100       141       131        79
# 4       231       232       232       247       248       200       135
#
#    pixel405  pixel406  pixel407  pixel408  pixel409  pixel410  pixel411  \
# 0        64        63        69        75        78        57       130
# 1       132       132       109       109       108        99       135
# 2       120       111        85        75       100       108        85
# 3       171       165        82        85       170       173       196
# 4       166       204       149       127       202       154       142
#
#    pixel412  pixel413  pixel414  pixel415  pixel416  pixel417  pixel418  \
# 0       165       158       159       158       159       158       157
# 1       142       111       163       154        77       156       172
# 2       190       220       213       212       210       210       210
# 3       194       173       137       132       180       112       145
# 4       123       154       116       187       223       211       211
#
#    pixel419  pixel420  pixel421  pixel422  pixel423  pixel424  pixel425  \
# 0       157       157       149       148       146       145       147
# 1       167       167       165       167       168       171       172
# 2       208       206        95        98       102       110       129
# 3       236       221       217       218       217       221       248
# 4       209       207       213       218       222       226       229
#
#    pixel426  pixel427  pixel428  pixel429  pixel430  pixel431  pixel432  \
# 0       149       146       151       144       110        78        65
# 1       173       173       174       169       170       182       150
# 2       148       164       167       198       181       101       120
# 3       235       206       169       123       109       140       103
# 4       232       232       240       251       234       220       177
#
#    pixel433  pixel434  pixel435  pixel436  pixel437  pixel438  pixel439  \
# 0        66        66        58        59        64        79       150
# 1       125       124       100       106       103       102       130
# 2       165       146       125        94        83        93        75
# 3       164       178       148       189       206       203       191
# 4       135       198       148       114       166       166       154
#
#    pixel440  pixel441  pixel442  pixel443  pixel444  pixel445  pixel446  \
# 0       165       162       162       162       162       161       161
# 1       138       124       178       130        64       168       172
# 2       179       224       215       215       214       213       211
# 3       177       154       137       114       117        91       138
# 4       134       149       103       177       226       213       213
#
#    pixel447  pixel448  pixel449  pixel450  pixel451  pixel452  pixel453  \
# 0       158       156       151       146       143       141       138
# 1       170       169       165       168       170       171       172
# 2       209       207        93        97       102       112       132
# 3       238       220       218       219       219       221       249
# 4       210       208       212       218       223       226       230
#
#    pixel454  pixel455  pixel456  pixel457  pixel458  pixel459  pixel460  \
# 0       140       142       146       144       121        84        56
# 1       174       175       174       175       172       195       170
# 2       149       166       173       189       195       158        91
# 3       243       214       182       164       151       142       164
# 4       233       232       255       250       221       229       182
#
#    pixel461  pixel462  pixel463  pixel464  pixel465  pixel466  pixel467  \
# 0        62        70        71        68        57       117       144
# 1       114       110        94        89        98       105       127
# 2       127       176       152       132       101        80        69
# 3       185       198       218       220       218       207       189
# 4       128       167       147       113       156       127       118
#
#    pixel468  pixel469  pixel470  pixel471  pixel472  pixel473  pixel474  \
# 0       144       147       149       152       150       146       146
# 1       134       124       182       126        80       180       171
# 2       156       228       215       216       216       214       212
# 3       170       143       121       113        92        73       131
# 4       148       127        93       174       229       214       215
#
#    pixel475  pixel476  pixel477  pixel478  pixel479  pixel480  pixel481  \
# 0       154       160       147       144       143       142       140
# 1       171       171       166       169       171       172       173
# 2       210       208        95        99       100       110       135
# 3       239       220       217       218       217       222       244
# 4       212       210       212       217       223       226       230
#
#    pixel482  pixel483  pixel484  pixel485  pixel486  pixel487  pixel488  \
# 0       142       146       151       154       131        85        59
# 1       174       175       176       177       174       197       179
# 2       147       186       190       153       207       171       108
# 3       243       223       200       185       173       160       160
# 4       232       232       249       242       194       200       180
#
#    pixel489  pixel490  pixel491  pixel492  pixel493  pixel494  pixel495  \
# 0        51        60        85        69        64        76        75
# 1       119        86        87        81        94       118       136
# 2       110       222       169       152       128        79        61
# 3       187       205       218       217       218       209       183
# 4       120       134       144        96       185       187       100
#
#    pixel496  pixel497  pixel498  pixel499  pixel500  pixel501  pixel502  \
# 0        79        81        79        76        83       112       141
# 1       123       116       177       127        94       183       172
# 2       108       226       217       218       218       216       215
# 3       164       142       114        99        93        66       159
# 4       170       156        95       150       230       214       213
#
#    pixel503  pixel504  pixel505  pixel506  pixel507  pixel508  pixel509  \
# 0       163       163       144       148       147       145       145
# 1       173       173       169       172       172       174       175
# 2       213       212        96        99       101       111       134
# 3       238       222       216       216       217       221       238
# 4       211       209       215       219       224       229       231
#
#    pixel510  pixel511  pixel512  pixel513  pixel514  pixel515  pixel516  \
# 0       148       150       155       151       119        74        62
# 1       174       177       178       178       175       192       176
# 2       146       200       221       149       156       161       113
# 3       238       231       215       204       182       170       165
# 4       234       236       238       238       212       199       159
#
#    pixel517  pixel518  pixel519  pixel520  pixel521  pixel522  pixel523  \
# 0        63        55        62        72        73        77        74
# 1       126        87        86        82       109       130       147
# 2       167       247       188       160       139        90        63
# 3       178       201       215       216       211       202       177
# 4        99       128       128        77       180       194       104
#
#    pixel524  pixel525  pixel526  pixel527  pixel528  pixel529  pixel530  \
# 0        73        68        88       113       138       162       162
# 1       159       128       164       128       100       184       174
# 2        92       223       221       220       219       219       217
# 3       157       136       110        96        76       113       222
# 4       152       162        92       130       230       215       214
#
#    pixel531  pixel532  pixel533  pixel534  pixel535  pixel536  pixel537  \
# 0       168       168       146       146       142       141       141
# 1       173       173       169       172       173       173       176
# 2       216       214        95        99       101       112       135
# 3       230       227       222       223       224       216       233
# 4       210       207       215       220       225       228       231
#
#    pixel538  pixel539  pixel540  pixel541  pixel542  pixel543  pixel544  \
# 0       138       134       142       124        96        75        67
# 1       178       179       178       181       175       189       171
# 2       150       187       222       172       113       168       151
# 3       239       240       229       210       187       171       168
# 4       234       236       242       251       233       211       148
#
#    pixel545  pixel546  pixel547  pixel548  pixel549  pixel550  pixel551  \
# 0        65        63        62        78        87        76        84
# 1       126        89        80        90       121       137       164
# 2       173       247       184       153       140       103        67
# 3       180       207       218       218       203       194       174
# 4       123       132       141       105       164       168       143
#
#    pixel552  pixel553  pixel554  pixel555  pixel556  pixel557  pixel558  \
# 0        96       126       162       172       155       144       149
# 1       175       141       140       108        95       184       176
# 2        90       226       223       222       222       220       218
# 3       153       129       107        80        97       213       227
# 4       145       133        87       174       227       213       214
#
#    pixel559  pixel560  pixel561  pixel562  pixel563  pixel564  pixel565  \
# 0       151       161       142       136       132       134       127
# 1       175       173       171       173       174       175       177
# 2       217       216        96        98       101       113       136
# 3       225       226       175       180       188       178       214
# 4       215       218       214       220       226       229       231
#
#    pixel566  pixel567  pixel568  pixel569  pixel570  pixel571  pixel572  \
# 0       119       118       119       103        87        77        73
# 1       179       179       179       181       174       189       171
# 2       155       168       194       184       123       170       201
# 3       240       245       233       210       191       174       167
# 4       234       235       240       255       240       226       153
#
#    pixel573  pixel574  pixel575  pixel576  pixel577  pixel578  pixel579  \
# 0        70        62        64        72        93       134       155
# 1       134        91        80        98       134       159       164
# 2       176       229       196       157       133       107        74
# 3       179       211       220       211       196       186       168
# 4       131       131       155       168       220       197       168
#
#    pixel580  pixel581  pixel582  pixel583  pixel584  pixel585  pixel586  \
# 0       160       166       156       150       151       143       136
# 1       167       153       114        73        82       185       176
# 2        88       225       224       224       224       222       220
# 3       143       118        96        78       196       239       230
# 4       147        97       115       229       227       228       225
#
#    pixel587  pixel588  pixel589  pixel590  pixel591  pixel592  pixel593  \
# 0       145       149       130       132       127       120       114
# 1       177       177       172       173       174       177       178
# 2       218       217        95        98       101       115       137
# 3       234       233        94        96       103        85       151
# 4       204       161       217       223       229       233       235
#
#    pixel594  pixel595  pixel596  pixel597  pixel598  pixel599  pixel600  \
# 0       110       109       105        91        77        74        75
# 1       179       180       180       183       174       186       172
# 2       155       167       183       185       125       169       250
# 3       244       234       226       211       195       181       165
# 4       238       241       243       255       249       221       169
#
#    pixel601  pixel602  pixel603  pixel604  pixel605  pixel606  pixel607  \
# 0        74        65        73       113       166       177       170
# 1       138        93        82        97       143       172       169
# 2       154       197       201       172       130       102        81
# 3       178       207       207       192       178       168       153
# 4       150       139       203       232       209       176       139
#
#    pixel608  pixel609  pixel610  pixel611  pixel612  pixel613  pixel614  \
# 0       161       152       141       134       136       140       133
# 1       160       132        89        44       108       189       176
# 2        86       224       226       225       224       224       222
# 3       129       107        86       104       177       178       182
# 4       131        93       182       234       193       166       138
#
#    pixel615  pixel616  pixel617  pixel618  pixel619  pixel620  pixel621  \
# 0       127       130       113       116       115       106       101
# 1       178       178       171       173       177       178       179
# 2       220       218        94        97       100       115       137
# 3       178       177       103       103       104        91       114
# 4        92        66       165       165       167       169       170
#
#    pixel622  pixel623  pixel624  pixel625  pixel626  pixel627  pixel628  \
# 0        95        86        84        85        77        78        74
# 1       180       181       182       185       178       179       170
# 2       156       171       173       198       163       190       173
# 3       239       220       212       211       202       188       164
# 4       170       167       167       238       245       212       191
#
#    pixel629  pixel630  pixel631  pixel632  pixel633  pixel634  pixel635  \
# 0        76       103       152       179       170       157       155
# 1       137        95        88        90       152       180       167
# 2       100       162       200       161       125        98        80
# 3       173       203       198       178       156       140       127
# 4       163       154       214       223       188       155       131
#
#    pixel636  pixel637  pixel638  pixel639  pixel640  pixel641  pixel642  \
# 0       151       140       129       126       126       133       130
# 1       141       112        65        64       176       183       179
# 2        95       228       227       226       225       224       223
# 3       115        95        92        99        95        90        86
# 4       118        95       124       103        65        50        47
#
#    pixel643  pixel644  pixel645  pixel646  pixel647  pixel648  pixel649  \
# 0       122       125        81        86        85        83        76
# 1       179       178       173       174       178       179       179
# 2       221       219        96        99       100       114       138
# 3       113       156       101       103       105        99       106
# 4        54        59       139       141       140       141       140
#
#    pixel650  pixel651  pixel652  pixel653  pixel654  pixel655  pixel656  \
# 0        72        73        76        77        79        71       101
# 1       180       182       183       186       175       165       168
# 2       157       173       174       190       225       194       116
# 3       230       209       204       214       204       185       164
# 4       137       140       124       201       244       213       195
#
#    pixel657  pixel658  pixel659  pixel660  pixel661  pixel662  pixel663  \
# 0       151       178       177       170       161       152       147
# 1       137       100        96        88       149       168       147
# 2       125       184       183       150       117        94        77
# 3       167       201       194       168       131       109       103
# 4       177       145       180       191       162       136       120
#
#    pixel664  pixel665  pixel666  pixel667  pixel668  pixel669  pixel670  \
# 0       151       133       115       121       121       124       126
# 1       122        92        50       144       193       181       181
# 2       112       236       226       229       227       225       224
# 3        93        93       104        98        97       131       187
# 4       100        70        49        47        50        57        54
#
#    pixel671  pixel672  pixel673  pixel674  pixel675  pixel676  pixel677  \
# 0       122       122        61        61        67        69        70
# 1       180       179       173       174       177       179       180
# 2       221       220        93        97        99       115       138
# 3       234       233       100       101       100       102       104
# 4        47        50       147       148       147       147       147
#
#    pixel678  pixel679  pixel680  pixel681  pixel682  pixel683  pixel684  \
# 0        75        78        78        81        68       113       165
# 1       180       183       182       187       177       158       161
# 2       157       170       175       177       211       222       197
# 3       222       207       205       215       199       183       172
# 4       148       158       126       124       242       215       194
#
#    pixel685  pixel686  pixel687  pixel688  pixel689  pixel690  pixel691  \
# 0       174       169       162       157       149       148       148
# 1       130       111       101        91       136       150       135
# 2       172       191       163       135       110        97        76
# 3       164       193       187       153       107        91        86
# 4       176       136       137       135       129       115       100
#
#    pixel692  pixel693  pixel694  pixel695  pixel696  pixel697  pixel698  \
# 0       148       126       100       113       117       113       122
# 1       112        62        87       192       183       185       183
# 2       132       239       224       227       227       225       224
# 3        93       102       108       141       195       241       242
# 4        70        53        56        57        49        48        58
#
#    pixel699  pixel700  pixel701  pixel702  pixel703  pixel704  pixel705  \
# 0       118       115        69        69        77        78        75
# 1       181       180       173       174       177       178       179
# 2       223       222        91        94        97       114       137
# 3       226       207       100       101       100       104        98
# 4        53        46       148       148       146       146       146
#
#    pixel706  pixel707  pixel708  pixel709  pixel710  pixel711  pixel712  \
# 0        76        78        79        67       120       173       157
# 1       179       181       182       184       179       156       151
# 2       156       170       172       180       199       217       200
# 3       222       224       209       212       193       178       175
# 4       146       148       121        64       148       207       197
#
#    pixel713  pixel714  pixel715  pixel716  pixel717  pixel718  pixel719  \
# 0       159       148       155       150       138       143       148
# 1       124       116        96        88       128       138       126
# 2       157       160       147       122       112       107        80
# 3       159       171       173       135        92        85        85
# 4       154       117       119       116       119        91        54
#
#    pixel720  pixel721  pixel722  pixel723  pixel724  pixel725  pixel726  \
# 0       149       123        91       101       111       111       116
# 1        81        49       164       190       184       185       184
# 2       145       239       225       227       227       225       224
# 3        92       120       208       252       255       246       237
# 4        69        46        43        53        52        44        48
#
#    pixel727  pixel728  pixel729  pixel730  pixel731  pixel732  pixel733  \
# 0       113       118        74        75        76        75        75
# 1       182       181       172       174       177       178       178
# 2       222       221        90        92        96       114       138
# 3       229       204       101       100       100       102        93
# 4        56        55       148       150       151       149       148
#
#    pixel734  pixel735  pixel736  pixel737  pixel738  pixel739  pixel740  \
# 0        76        75        68       124       172       152       146
# 1       178       180       182       184       177       160       154
# 2       155       171       174       185        90       179       207
# 3       220       233       219       210       191       179       182
# 4       149       143        95        79        74       115       144
#
#    pixel741  pixel742  pixel743  pixel744  pixel745  pixel746  pixel747  \
# 0       146       146       152       142       131       134       144
# 1       128       114        97        78       114       112        89
# 2       143       164       167       163       145       123        78
# 3       155       159       164       123        85        80        84
# 4       125       120       112       105        93        52        24
#
#    pixel748  pixel749  pixel750  pixel751  pixel752  pixel753  pixel754  \
# 0       147       125        87        87       103       107       110
# 1        48       133       194       182       185       184       184
# 2       162       239       227       229       226       226       225
# 3       151       238       255       255       250       237       245
# 4        53        63        33        41        51        48        45
#
#    pixel755  pixel756  pixel757  pixel758  pixel759  pixel760  pixel761  \
# 0       116       113        75        74        74        74        76
# 1       182       181       172       174       177       178       178
# 2       224       222        89        91        94       111       136
# 3       250       232       103       101       102       103        95
# 4        49        55       149       150       150       148       147
#
#    pixel762  pixel763  pixel764  pixel765  pixel766  pixel767  pixel768  \
# 0        74        82       134       168       155       146       137
# 1       179       181       183       187       175       165       154
# 2       154       167       184       125         3       166       225
# 3       208       231       227       209       190       179       182
# 4       151       124        82        84        81        69        81
#
#    pixel769  pixel770  pixel771  pixel772  pixel773  pixel774  pixel775  \
# 0       145       146       149       135       124       125       138
# 1       118       107       100        75        96        83        47
# 2       195       188       172       185       161       122        68
# 3       152       150       159       119        83        63       154
# 4       111       103        84        75        53        28        26
#
#    pixel776  pixel777  pixel778  pixel779  pixel780  pixel781  pixel782  \
# 0       148       127        89        82        96       106       112
# 1       104       194       183       186       184       184       184
# 2       166       242       227       230       227       226       225
# 3       248       247       248       253       236       230       240
# 4        40        64        48        29        46        49        46
#
#    pixel783  pixel784
# 0       120       107
# 1       182       180
# 2       224       222
# 3       253       255
# 4        46        53

# %%
# trainとtestでcsvが用意されていたのでそれを目的変数yと説明変数Xに分割
y_train = train_base['label'].values
X_train = train_base.drop(columns='label').values.reshape(len(train_base), 28,28,1)
y_test = test_base['label'].values
X_test = test_base.drop(columns='label').values.reshape(len(test_base), 28,28,1)

# 検証データを用意(割合はtestデータと同じ)
size = len(test_base) / (len(train_base) + len(test_base))
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=size, random_state=0)

# %%
rand_num = random.randint(0, len(X_train)-1)
plt.imshow(X_train[rand_num])
plt.title(label_dict[y_train[rand_num]])
plt.show()

# %%
# One-hotエンコード
y_train = tf.one_hot(y_train, 25)
y_valid = tf.one_hot(y_valid, 25)
y_test = tf.one_hot(y_test, 25)

# データの確認
print(f"y_train={y_train.shape}, y_valid={y_valid.shape}, y_test={y_test.shape}")
print(f"X_train={X_train.shape}, X_valid={X_valid.shape}, X_test={X_test.shape}")
# Out:
# y_train=(21768, 25), y_valid=(5687, 25), y_test=(7172, 25)
# X_train=(21768, 28, 28, 1), X_valid=(5687, 28, 28, 1), X_test=(7172, 28, 28, 1)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(28, 28, 1)),
    tf.keras.layers.Rescaling(1./255),

    tf.keras.layers.Conv2D(16, kernel_size=3, padding="same", strides=1, activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Conv2D(32, kernel_size=3, padding="same", strides=1, activation="relu"),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(25, activation='softmax')
])

# モデルの構築
model.compile(optimizer = "adam", loss="categorical_crossentropy", metrics=['accuracy'])

# %%
# %%time
# 学習の実施
log = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=True,
                callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=50, verbose=1)],
                validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.1663 - loss: 2.7952 - val_accuracy: 0.6735 - val_loss: 1.5140
# Epoch 2/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4401 - loss: 1.7275 - val_accuracy: 0.7990 - val_loss: 0.9096
# Epoch 3/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5224 - loss: 1.4588 - val_accuracy: 0.8593 - val_loss: 0.7151
# Epoch 4/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5803 - loss: 1.2874 - val_accuracy: 0.9130 - val_loss: 0.5922
# Epoch 5/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6124 - loss: 1.1928 - val_accuracy: 0.9344 - val_loss: 0.4879
# Epoch 6/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6409 - loss: 1.1109 - val_accuracy: 0.9559 - val_loss: 0.4566
# Epoch 7/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6624 - loss: 1.0573 - val_accuracy: 0.9671 - val_loss: 0.3921
# Epoch 8/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6787 - loss: 1.0071 - val_accuracy: 0.9657 - val_loss: 0.3974
# Epoch 9/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6918 - loss: 0.9798 - val_accuracy: 0.9785 - val_loss: 0.3346
# Epoch 10/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7021 - loss: 0.9538 - val_accuracy: 0.9840 - val_loss: 0.3099
# Epoch 11/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7092 - loss: 0.9199 - val_accuracy: 0.9810 - val_loss: 0.2849
# Epoch 12/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7241 - loss: 0.8915 - val_accuracy: 0.9917 - val_loss: 0.2671
# Epoch 13/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7270 - loss: 0.8838 - val_accuracy: 0.9942 - val_loss: 0.2631
# Epoch 14/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7399 - loss: 0.8469 - val_accuracy: 0.9956 - val_loss: 0.2497
# Epoch 15/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7386 - loss: 0.8500 - val_accuracy: 0.9930 - val_loss: 0.2362
# Epoch 16/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7517 - loss: 0.8134 - val_accuracy: 0.9967 - val_loss: 0.2166
# Epoch 17/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7562 - loss: 0.8112 - val_accuracy: 0.9961 - val_loss: 0.2122
# Epoch 18/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7587 - loss: 0.7958 - val_accuracy: 0.9935 - val_loss: 0.2115
# Epoch 19/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7659 - loss: 0.7800 - val_accuracy: 0.9989 - val_loss: 0.2047
# Epoch 20/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7670 - loss: 0.7666 - val_accuracy: 0.9995 - val_loss: 0.2035
# Epoch 21/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7686 - loss: 0.7687 - val_accuracy: 0.9977 - val_loss: 0.1989
# Epoch 22/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7685 - loss: 0.7582 - val_accuracy: 0.9996 - val_loss: 0.1994
# Epoch 23/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7816 - loss: 0.7366 - val_accuracy: 0.9968 - val_loss: 0.1804
# Epoch 24/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7800 - loss: 0.7318 - val_accuracy: 0.9998 - val_loss: 0.1757
# Epoch 25/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7835 - loss: 0.7307 - val_accuracy: 0.9995 - val_loss: 0.1797
# Epoch 26/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7893 - loss: 0.7107 - val_accuracy: 0.9984 - val_loss: 0.1702
# Epoch 27/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7885 - loss: 0.7175 - val_accuracy: 0.9996 - val_loss: 0.1713
# Epoch 28/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7893 - loss: 0.7104 - val_accuracy: 0.9996 - val_loss: 0.1636
# Epoch 29/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7917 - loss: 0.7021 - val_accuracy: 1.0000 - val_loss: 0.1622
# Epoch 30/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7958 - loss: 0.6885 - val_accuracy: 0.9993 - val_loss: 0.1624
# Epoch 31/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7969 - loss: 0.6792 - val_accuracy: 0.9996 - val_loss: 0.1583
# Epoch 32/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8003 - loss: 0.6860 - val_accuracy: 0.9996 - val_loss: 0.1660
# Epoch 33/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8030 - loss: 0.6657 - val_accuracy: 0.9998 - val_loss: 0.1540
# Epoch 34/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8015 - loss: 0.6755 - val_accuracy: 0.9989 - val_loss: 0.1547
# Epoch 35/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7975 - loss: 0.6797 - val_accuracy: 1.0000 - val_loss: 0.1568
# Epoch 36/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8054 - loss: 0.6686 - val_accuracy: 1.0000 - val_loss: 0.1537
# Epoch 37/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8071 - loss: 0.6639 - val_accuracy: 0.9996 - val_loss: 0.1502
# Epoch 38/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8065 - loss: 0.6571 - val_accuracy: 0.9996 - val_loss: 0.1578
# Epoch 39/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8050 - loss: 0.6605 - val_accuracy: 1.0000 - val_loss: 0.1494
# Epoch 40/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8094 - loss: 0.6528 - val_accuracy: 1.0000 - val_loss: 0.1499
# Epoch 41/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8067 - loss: 0.6590 - val_accuracy: 1.0000 - val_loss: 0.1493
# Epoch 42/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8129 - loss: 0.6456 - val_accuracy: 0.9996 - val_loss: 0.1498
# Epoch 43/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8144 - loss: 0.6394 - val_accuracy: 1.0000 - val_loss: 0.1436
# Epoch 44/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8074 - loss: 0.6440 - val_accuracy: 0.9989 - val_loss: 0.1480
# Epoch 45/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8134 - loss: 0.6444 - val_accuracy: 0.9998 - val_loss: 0.1442
# Epoch 46/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8121 - loss: 0.6374 - val_accuracy: 1.0000 - val_loss: 0.1423
# Epoch 47/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8188 - loss: 0.6280 - val_accuracy: 0.9996 - val_loss: 0.1440
# Epoch 48/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8149 - loss: 0.6309 - val_accuracy: 1.0000 - val_loss: 0.1399
# Epoch 49/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8126 - loss: 0.6340 - val_accuracy: 1.0000 - val_loss: 0.1474
# Epoch 50/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8167 - loss: 0.6365 - val_accuracy: 0.9989 - val_loss: 0.1526
# Epoch 51/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8190 - loss: 0.6215 - val_accuracy: 0.9996 - val_loss: 0.1406
# Epoch 52/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8212 - loss: 0.6159 - val_accuracy: 1.0000 - val_loss: 0.1414
# Epoch 53/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8218 - loss: 0.6183 - val_accuracy: 0.9995 - val_loss: 0.1428
# Epoch 54/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8243 - loss: 0.6118 - val_accuracy: 1.0000 - val_loss: 0.1375
# Epoch 55/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8249 - loss: 0.6080 - val_accuracy: 1.0000 - val_loss: 0.1347
# Epoch 56/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8220 - loss: 0.6173 - val_accuracy: 1.0000 - val_loss: 0.1391
# Epoch 57/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8212 - loss: 0.6155 - val_accuracy: 1.0000 - val_loss: 0.1409
# Epoch 58/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8207 - loss: 0.6136 - val_accuracy: 0.9998 - val_loss: 0.1426
# Epoch 59/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8320 - loss: 0.5929 - val_accuracy: 1.0000 - val_loss: 0.1368
# Epoch 60/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8252 - loss: 0.6084 - val_accuracy: 1.0000 - val_loss: 0.1402
# Epoch 61/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8272 - loss: 0.6042 - val_accuracy: 1.0000 - val_loss: 0.1377
# Epoch 62/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8255 - loss: 0.6085 - val_accuracy: 1.0000 - val_loss: 0.1391
# Epoch 63/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8277 - loss: 0.5996 - val_accuracy: 1.0000 - val_loss: 0.1371
# Epoch 64/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8274 - loss: 0.5995 - val_accuracy: 1.0000 - val_loss: 0.1371
# Epoch 65/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8341 - loss: 0.5855 - val_accuracy: 0.9998 - val_loss: 0.1367
# Epoch 66/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8290 - loss: 0.5936 - val_accuracy: 0.9996 - val_loss: 0.1353
# Epoch 67/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8295 - loss: 0.5984 - val_accuracy: 0.9998 - val_loss: 0.1411
# Epoch 68/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8328 - loss: 0.5854 - val_accuracy: 1.0000 - val_loss: 0.1344
# Epoch 69/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8317 - loss: 0.5852 - val_accuracy: 1.0000 - val_loss: 0.1335
# Epoch 70/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8295 - loss: 0.5927 - val_accuracy: 1.0000 - val_loss: 0.1382
# Epoch 71/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8318 - loss: 0.5862 - val_accuracy: 1.0000 - val_loss: 0.1334
# Epoch 72/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8352 - loss: 0.5844 - val_accuracy: 1.0000 - val_loss: 0.1335
# Epoch 73/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8323 - loss: 0.5876 - val_accuracy: 0.9996 - val_loss: 0.1357
# Epoch 74/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8331 - loss: 0.5888 - val_accuracy: 0.9998 - val_loss: 0.1367
# Epoch 75/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8335 - loss: 0.5878 - val_accuracy: 1.0000 - val_loss: 0.1315
# Epoch 76/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8356 - loss: 0.5760 - val_accuracy: 1.0000 - val_loss: 0.1308
# Epoch 77/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8365 - loss: 0.5786 - val_accuracy: 0.9998 - val_loss: 0.1311
# Epoch 78/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8359 - loss: 0.5750 - val_accuracy: 1.0000 - val_loss: 0.1318
# Epoch 79/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8365 - loss: 0.5753 - val_accuracy: 0.9998 - val_loss: 0.1304
# Epoch 80/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8382 - loss: 0.5760 - val_accuracy: 0.9998 - val_loss: 0.1305
# Epoch 81/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8388 - loss: 0.5779 - val_accuracy: 0.9993 - val_loss: 0.1315
# Epoch 82/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8407 - loss: 0.5659 - val_accuracy: 1.0000 - val_loss: 0.1304
# Epoch 83/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8417 - loss: 0.5666 - val_accuracy: 1.0000 - val_loss: 0.1286
# Epoch 84/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8366 - loss: 0.5753 - val_accuracy: 0.9996 - val_loss: 0.1317
# Epoch 85/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8410 - loss: 0.5709 - val_accuracy: 1.0000 - val_loss: 0.1367
# Epoch 86/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8372 - loss: 0.5729 - val_accuracy: 1.0000 - val_loss: 0.1308
# Epoch 87/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8430 - loss: 0.5535 - val_accuracy: 1.0000 - val_loss: 0.1281
# Epoch 88/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8427 - loss: 0.5586 - val_accuracy: 1.0000 - val_loss: 0.1302
# Epoch 89/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8456 - loss: 0.5611 - val_accuracy: 1.0000 - val_loss: 0.1307
# Epoch 90/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8443 - loss: 0.5610 - val_accuracy: 1.0000 - val_loss: 0.1290
# Epoch 91/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8441 - loss: 0.5638 - val_accuracy: 1.0000 - val_loss: 0.1282
# Epoch 92/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8438 - loss: 0.5535 - val_accuracy: 0.9998 - val_loss: 0.1319
# Epoch 93/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8422 - loss: 0.5637 - val_accuracy: 0.9998 - val_loss: 0.1300
# Epoch 94/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8439 - loss: 0.5659 - val_accuracy: 1.0000 - val_loss: 0.1286
# Epoch 95/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8462 - loss: 0.5561 - val_accuracy: 1.0000 - val_loss: 0.1303
# Epoch 96/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8477 - loss: 0.5535 - val_accuracy: 0.9998 - val_loss: 0.1299
# Epoch 97/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8424 - loss: 0.5608 - val_accuracy: 1.0000 - val_loss: 0.1296
# Epoch 98/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8438 - loss: 0.5627 - val_accuracy: 1.0000 - val_loss: 0.1285
# Epoch 99/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8450 - loss: 0.5619 - val_accuracy: 0.9998 - val_loss: 0.1296
# Epoch 100/100
# 681/681 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8451 - loss: 0.5574 - val_accuracy: 0.9998 - val_loss: 0.1296
# CPU times: total: 24min 5s
# Wall time: 6min 41s

# %%
plt.plot(log.history['loss'], label='loss')
plt.plot(log.history['val_loss'], label='val_loss')
plt.legend(frameon=False)
plt.xlabel("epochs")
plt.ylabel("crossentropy")
# Out:
# Text(0, 0.5, 'crossentropy')

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
y_test_ = np.argmax(y_test, axis=1)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
print(classification_report(y_test_, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       331
#            1       1.00      0.97      0.99       432
#            2       0.97      1.00      0.99       310
#            3       0.99      1.00      0.99       245
#            4       0.98      0.96      0.97       498
#            5       0.92      1.00      0.96       247
#            6       0.93      0.93      0.93       348
#            7       0.92      0.92      0.92       436
#            8       0.99      0.78      0.87       288
#           10       0.99      0.89      0.93       331
#           11       1.00      1.00      1.00       209
#           12       0.85      0.92      0.88       394
#           13       0.94      0.77      0.85       291
#           14       1.00      0.96      0.98       246
#           15       1.00      0.99      0.99       347
#           16       0.97      1.00      0.98       164
#           17       0.65      0.75      0.70       144
#           18       0.78      0.99      0.87       246
#           19       0.93      0.87      0.90       248
#           20       0.93      0.85      0.89       266
#           21       0.84      0.95      0.89       346
#           22       0.89      0.90      0.90       206
#           23       0.95      1.00      0.97       267
#           24       0.88      0.89      0.88       332
#
#     accuracy                           0.93      7172
#    macro avg       0.93      0.93      0.93      7172
# weighted avg       0.94      0.93      0.93      7172
